# %%
#Análise em base de dados da Chegada de Turistas Internacionais

#importação de bibliotecas que trabalham com dados tabulados
import numpy as np
import pandas as pd

# %%
#armazenando os dados tabulados do dataset
dataSet1 = pd.read_csv("chegadas_2010.csv", delimiter=';', encoding='latin-1') 
dataSet1
# Out:
#                         Continente  Ordem continente  \
# 0                           África                 1
# 1                           África                 1
# 2                           África                 1
# 3                           África                 1
# 4                           África                 1
# ...                            ...               ...
# 22171                       Europa                 6
# 22172                      Oceania                 7
# 22173                      Oceania                 7
# 22174                      Oceania                 7
# 22175  Continente não especificado                 8
#
#                            País  Ordem país                 UF  Ordem UF  \
# 0                 África do Sul           2           Amazonas         4
# 1                        Angola           6           Amazonas         4
# 2                    Cabo Verde          35           Amazonas         4
# ...

# %%
#armazenando os dados tabulados do dataset
dataSet2 = pd.read_csv("chegadas_2011.csv", delimiter=';', encoding='latin-1') 
dataSet2
# Out:
#                         Continente  Ordem continente  \
# 0                           África                 1
# 1                           África                 1
# 2                           África                 1
# 3                           África                 1
# 4                           África                 1
# ...                            ...               ...
# 22171                       Europa                 6
# 22172                      Oceania                 7
# 22173                      Oceania                 7
# 22174                      Oceania                 7
# 22175  Continente não especificado                 8
#
#                            País  Ordem país                            UF  \
# 0                 África do Sul           2                      Amazonas
# 1                        Angola           6                      Amazonas
# 2                    Cabo Verde          35                      Amazonas
# ...

# %%
#Unindo duas colunas
#relacao_colunas = {'A':'X', 'B':'Y', 'C':'Z'}
#df_concat = pd.concat([df1, df2.rename(columns=relacao_colunas)])

dataSetConcat = pd.concat([dataSet1, dataSet2])
dataSetConcat
# Out:
#                         Continente  Ordem continente  \
# 0                           África                 1
# 1                           África                 1
# 2                           África                 1
# 3                           África                 1
# 4                           África                 1
# ...                            ...               ...
# 22171                       Europa                 6
# 22172                      Oceania                 7
# 22173                      Oceania                 7
# 22174                      Oceania                 7
# 22175  Continente não especificado                 8
#
#                            País  Ordem país                            UF  \
# 0                 África do Sul           2                      Amazonas
# 1                        Angola           6                      Amazonas
# 2                    Cabo Verde          35                      Amazonas
# ...

# %%
#armazenando os dados tabulados do dataset
dataSet1 = pd.read_csv("chegadas_2010.csv", delimiter=';', encoding='latin-1') 
dataSet2 = pd.read_csv("chegadas_2011.csv", delimiter=';', encoding='latin-1')
dataSet3 = pd.read_csv("chegadas_2011.csv", delimiter=';', encoding='latin-1')
dataSet4 = pd.read_csv("chegadas_2012.csv", delimiter=';', encoding='latin-1')
dataSet5 = pd.read_csv("chegadas_2013.csv", delimiter=';', encoding='latin-1')
dataSet6 = pd.read_csv("chegadas_2014.csv", delimiter=';', encoding='latin-1')
dataSet7 = pd.read_csv("chegadas_2015.csv", delimiter=';', encoding='latin-1')
dataSet8 = pd.read_csv("chegadas_2016.csv", delimiter=';', encoding='latin-1')
dataSet9 = pd.read_csv("chegadas_2017.csv", delimiter=';', encoding='latin-1')
dataSet10 = pd.read_csv("chegadas_2018.csv", delimiter=';', encoding='latin-1')
dataSet11 = pd.read_csv("chegadas_2019.csv", delimiter=';', encoding='latin-1')

# %%
dataSetConcat = pd.concat([dataSet1, dataSet2, dataSet3, dataSet4, dataSet5, dataSet6, dataSet7, dataSet8, dataSet9, dataSet10, dataSet11])
dataSetConcat
# Out:
#       Continente  Ordem continente           País  Ordem país         UF  \
# 0         África               1.0  África do Sul         2.0   Amazonas
# 1         África               1.0         Angola         6.0   Amazonas
# 2         África               1.0     Cabo Verde        35.0   Amazonas
# 3         África               1.0        Nigéria       162.0   Amazonas
# 4         África               1.0  Outros países       998.0   Amazonas
# ...          ...               ...            ...         ...        ...
# 49099    Oceania               NaN  Outros países         NaN  São Paulo
# 49100    Oceania               NaN  Outros países         NaN  São Paulo
# 49101    Oceania               NaN  Outros países         NaN  São Paulo
# 49102    Oceania               NaN  Outros países         NaN  São Paulo
# 49103    Oceania               NaN  Outros países         NaN  São Paulo
#
#        Ordem UF Via de acesso  Ordem via de acesso     Ano       Mês  ...  \
# ...

# %%
dataSetConcat.describe()
# Out:
#        Ordem continente     Ordem país       Ordem UF  Ordem via de acesso  \
# count     184632.000000  184632.000000  184632.000000        184632.000000
# mean           4.548876     194.173859      23.992071             2.107825
# std            1.817953     270.665514      26.664959             1.099502
# min            1.000000       2.000000       1.000000             1.000000
# 25%            4.000000      55.000000      12.000000             1.000000
# 50%            5.000000     117.000000      17.000000             2.000000
# 75%            6.000000     184.000000      23.000000             3.000000
# max            8.000000     999.000000      99.000000             4.000000
#
#                  Ano      Ordem mês       Chegadas  Unnamed: 12  \
# count  137760.000000  184632.000000  366084.000000          0.0
# mean     2011.907317       6.500000     181.280649          NaN
# std         1.381484       3.452062    2167.119506          NaN
# ...
